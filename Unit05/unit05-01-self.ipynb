# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []
#result라는 list에 값을 저장하겠다.

for row in data:
    if row[-1] !='': 
        result.append(float(row[-1]))

plt.figure(figsize =(10,2), dpi =300) #figure는 하나의 캔버스, 그림 그릴 수 있는 사이즈
plt.plot(result,'r')

#print(result)
print(len(result))
# Out:
# 39463

# %%
plt.figure(figsize =(10,2), dpi =300) #figure는 하나의 캔버스, 그림 그릴 수 있는 사이즈
plt.plot(result,'r')

plt.show()

# %%
s = 'hello python'
print(s)
# Out:
# hello python

# %%
date = '1907-10-01'

# %%
print(date.split('-'))
a = date.split('-')
print(a)
# Out:
# ['1907', '10', '01']
# ['1907', '10', '01']

# %%
print(date.split('-')[0])

print(a[1])
print(a[2])
# Out:
# 1907
# 10
# 01

# %%
date = '2021-10-25'
print(type(date))
print(date.split('-'))
a = date.split('-')
print(date)
print(a)
print(type(date.split('-')))


print(date.split('-')[0])
print(date.split('-')[1])
print(date.split('-')[2])
# Out:
# <class 'str'>
# ['2021', '10', '25']
# 2021-10-25
# ['2021', '10', '25']
# <class 'list'>
# 2021
# 10
# 25

# %%
s = 'hello Python'
print(s.split())
# Out:
# ['hello', 'Python']

# %%
import csv

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] !='':
        if row[0].split('-')[1] == '08':
            result.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.plot(result, 'green') #green / hotpink 다양하게 색깔을 바꿀 수 있다.
plt.show()

# %%
import csv

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] !='':
        if row[0].split('-')[1] =='06' and row[0].split('-')[2] and row[0].split('-')[2] == '03':
            result.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.plot(result, 'violet') #green / hotpink 다양하게 색깔을 바꿀 수 있다.
plt.show()

# %%
import csv

f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] !='':
        if row[0].split('-')[1] =='12' and row[0].split('-')[2] and row[0].split('-')[2] == '30':
            result.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.plot(result, 'gold') #green / hotpink 다양하게 색깔을 바꿀 수 있다.
plt.show()
print(row)
# Out:
# ['2019-01-17', '108', '-0.3', '-3.2', '4']

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)

high = []  #최고 기온 값을 저장할 리스트 high 생성
low = [] #최저 기온 값 저장할 리스트 log 생성

for row in data :
    if row[-1] !='' and row[-2] !='': #최고기온값과 최저기온 값이 존재한다면,
        if row[0].split('-')[1] =='02' and row [0].split('-')[2] =='14' :
            high.append(float(row[-1]))
            low.append(float(row[-2]))
            
plt.figure(dpi =100)
plt.plot(high,'hotpink')
plt.plot(low,'skyblue')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('seoul.csv')
data = csv.reader(f)
next(data)

high=[]
low=[]

for row in data:
    if row[-1] !='' and row[-2] !='':
        date = row[0].split('-')
        if 1983 <= int(date[0]):
            if row[0].split('-')[1] =='02' and row [0].split('-')[2] =='14' :
                high.append(float(row[-1]))
                low.append(float(row[-2]))

#rc parameter
plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False #- 영하 기온이 깨짐방지 되기 위해 넣은 코드
plt.title('내 생일의 기온 변화 그래프')
plt.plot(high,'hotpink', label='high')
plt.plot(low, 'skyblue', label = 'low')

plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
 
f = open('seoul.csv')
data = csv.reader(f)
next(data)
high = []    # 최고 기온 값을 저장할 리스트 high 생성
low = []     # 최저 기온 값을 저장할 리스트 low 생성
 
for row in data :
    if row[-1] != '' and row[-2] != '' : # 최고 기온 값과 최저 기온 값이 존재한다면
        if 1983 <= int(row[0].split('-')[0]) :  # 1983년 이후 데이터라면
            if row[0].split('-')[1] == '02' and row[0].split('-')[2] == '14' :
                                            # 2월 14일이라면
                high.append(float(row[-1])) # 최고 기온 값을 high 리스트에 저장
                low.append(float(row[-2]))  # 최저 기온 값을 low 리스트에 저장
 
plt.plot(high, 'hotpink')  # high 리스트에 저장된 값을 hotpink 색으로 그리기
plt.plot(low, 'skyblue')   # low 리스트에 저장된 값을 skyblue 색으로 그리기
plt.show()                 # 그래프 나타내기

# %%
import csv
import matplotlib.pyplot as plt


f = open('seoul.csv')
data = csv.reader(f)
next(data)
high = []   # 최고 기온 값을 저장할 리스트 high 생성
low = []    # 최저 기온 값을 저장할 리스트 low 생성



for row in data :
    if row[-1] != '' and row[-2] != '' : # 최고 기온 값과 최저 기온 값이 존재한다면
        date = row[0].split('-')   # 날짜 값을 – 문자를 기준으로 구분하여 저장
        if 1983 <= int(date[0]) :  # 1983년 이후 데이터라면
            if date[1] == '02' and date[2] == '14' : # 2월 14일이라면
                high.append(float(row[-1])) # 최고 기온 값을 high 리스트에 저장
                low.append(float(row[-2])) # 최저 기온 값을 low 리스트에 저장



plt.rc('font', family='Malgun Gothic')     # 맑은 고딕을 기본 글꼴로 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지
plt.title('내 생일의 기온 변화 그래프')      # 제목 설정
# high 리스트에 저장된 값을 hotpink 색으로 그리고 레이블을 표시
plt.plot(high, 'hotpink', label='high')
# low 리스트에 저장된 값을 skyblue 색으로 그리고 레이블을 표시
plt.plot(low, 'skyblue', label='low')
plt.legend()          # 범례 표시
plt.show()            # 그래프 나타내기

# %%
import matplotlib.pyplot as plt
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] !='':
        result.append(float(row[-1]))

plt.hist([1,1,2,3,4,5,6,6,7,8,10])
#plt.figure(dpi=300)
plt.show()

# %%
#주사위 문제
import random 
dice = []
for i in range(5):
    dice.append(random.randint(1,6))
print(dice)
# Out:
# [3, 4, 6, 4, 6]

# %%
#주사위 문제
import random 
#
for i in range(5):
    print(random.randint(1,6))
# Out:
# 6
# 5
# 2
# 6
# 3

# %%
#주사위 문제
import random 
dice = []
for i in range(5):
    dice.append(random.randint(1,6))
print(dice)

import matplotlib.pyplot as plt
plt.hist(dice,bins=6)
#plt.figure(dpi=300)
plt.show()
# Out:
# [6, 1, 2, 1, 6]

# %%
#주사위 문제
import random 
dice = []
for i in range(100):
    dice.append(random.randint(1,6))
print(dice)

import matplotlib.pyplot as plt
plt.hist(dice, bins=6)
#plt.figure(dpi=300)
plt.show()
# Out:
# [2, 1, 4, 5, 2, 6, 1, 2, 4, 5, 4, 3, 3, 2, 3, 2, 1, 3, 1, 1, 2, 6, 1, 2, 2, 2, 5, 4, 6, 6, 5, 3, 4, 4, 2, 4, 6, 4, 3, 2, 2, 4, 6, 4, 6, 4, 6, 2, 1, 6, 3, 2, 6, 4, 6, 6, 2, 2, 5, 2, 5, 5, 5, 3, 6, 5, 4, 1, 4, 4, 4, 6, 6, 3, 3, 5, 2, 3, 5, 5, 5, 1, 2, 6, 1, 6, 5, 3, 4, 2, 1, 2, 2, 5, 4, 4, 1, 6, 5, 3]

# %%
#주사위 문제
import random 
dice = []
for i in range(1000000):
    dice.append(random.randint(1,6))

import matplotlib.pyplot as plt
plt.hist(dice, bins=6)
#plt.figure(dpi=300)
plt.show()

# %%
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.hist(result, bins=100, color= 'r')
plt.show()
print(row)
# Out:
# ['2019-01-17', '108', '-0.3', '-3.2', '4']

# %%
plt.figure(dpi = 150)
plt.hist(result, bins=1000, color= 'r')
plt.show()
print(row)
# Out:
# ['2019-01-17', '108', '-0.3', '-3.2', '4']

# %%
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data:
    month = row[0].split('-')[1]
    if row[-1] !='':
        if month =='08':
            aug.append(float(row[-1]))
            
import matplotlib.pyplot as plt
plt.hist(aug, bins = 100, color='y')
plt.show()

# %%
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data:
    month = row[0].split('-')[1]
    if row[-1] !='':
        if month =='08':
            aug.append(float(row[-1]))
        if month =='01':
            jan.append(float(row[-1]))
            
import matplotlib.pyplot as plt
plt.hist(aug, bins = 100, color='y')
plt.hist(jan, bins=100, color ='skyblue', label='Jan')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plot
import random

result = []

for i in range(13):
    result.append(random.randint(1,1000))
print(sorted(result))
# Out:
# [60, 102, 106, 187, 276, 330, 404, 470, 789, 824, 828, 831, 860]

# %%
#boxplot 형태
import matplotlib.pyplot as plot
import random

result = []

for i in range(13):
    result.append(random.randint(1,1000))
print(sorted(result))

import numpy as np
result = np.array(result)
#print("1/4:"+ str(np.percentile(result,25)))
#print("2/4:"+ str(np.percentile(result,55)))
print("3/4:"+ str(np.percentile(result,75)))
plt.boxplot(result)
plt.show()
# Out:
# [48, 57, 58, 124, 269, 594, 615, 772, 861, 877, 894, 900, 930]
# 3/4:877.0

# %%
#더운 달, 추운 달 boxplot으로 표현하기#

import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)

aug = []
jan = []

for row in data:
    month = row[0].split('-')[-1]
    if row [-1] !='':
        if month =='08':  #'==' ~이라면,
            aug.append(float(row[-1]))
        if month =='01':
            jan.append(float(row[-1]))

plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
#더운 달, 추운 달 boxplot으로 표현하기#

import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)

aug = []
jan = []

for row in data:
    month = row[0].split('-')[-1]
    if row [-1] !='':
        if month =='08':  #'==' ~이라면,
            aug.append(float(row[-1]))
        if month =='01':
            jan.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.boxplot([aug, jan])
plt.show()

# %%
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data :
    month = row[0].split('-')[1]
    if row[-1] != '' :
        if month == '08':
            aug.append(float(row[-1]))
        if month == '01':
            jan.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
f = open('seoul.csv')

data = csv.reader(f)
next(data)

month=[[], [], [], [], [], [], [], [], [], [], [], []]

for row in data:
    if row[-1] !='':
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))

plt.boxplot(month)
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

f = open ('seoul.csv')

data = csv.reader(f)
next(data)

day = [[] for i in range(31)]

for row in data:
    if row[-1] !='':
        if row[0].split('-')[1] =='08':
            day[int(row[0].split('-')[2])-1].append(float(row[-1]))

plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi = 300)
plt.boxplot(day, showfliers=False)
plt.show()
